# %%
from py_files.setup import *
setup_notebook()

from py_files.QP_diagram import make_figure

# %% [markdown]
# # Key `Uzawa` mechanism

# %% [markdown]
# **Goal:** Replicate QP-diagram like figure as in the `stylised model`, but for the quantitative.
# - Maybe show for different $\phi$ or $\alpha_K-\beta_K$.
# - To be presented as a link between the empirical and simulated results.

# %%
fig = make_figure(save_path="0_output/cap_market_quant")
# Out:
# Saved: 0_output/cap_market_quant{.png}
