# %% [markdown]
# # `Project overview` for keeping track of progress

# %% [markdown]
# ### `1. To do`
# 1. Make general bullet version of the draft - for discussion with Søren
#
#
# ### `2. Important issues`
# 1. Consumption wage goes down, yet welfare gain is positive, how can this be true?
# 2. Maybe reorder disposition:
# - Introduction
# - Literature review
# - Empirical evidence
# - Model framework
# - Quantitative model: with the phi calibration section
# - Simulations

# %% [markdown]
# git fetch origin
#
# git reset --hard origin/main
