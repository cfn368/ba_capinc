# %% [markdown]
# # `Project overview` for keeping track of progress

# %% [markdown]
# ### `1. To do`
#
# 1. State closed form solutions to the measurements in the second panel of the simulaiton.
# 2. Remove the simulation condition, $q_t=q_{ss}$; it's unnecassary numerically and not sound economically.
# 3. Understand simulation better.
# 4. Test sanity but comparison to their tables.
# 5. Start the `Empirical part`

# %% [markdown]
# ### `2. Current issues`
#
# #### `2.1 Mathematical model`
#
# 4. Some definition of a before tax capital rental rate has to be made in order to explicitly derive the stated demand curve.
# 5. My tax effects show up positively rather than negatively
#
#
# #### `2.2 Simulation`
#
# 1. $q_t$ crosses $p_{I,t}$.
# 2. Not hitting their tables, using the stated calibrationS

# %% [markdown]
# ### `2.3 Empirical`
#
# Output to generate from *dst*:
#
# 1. Types of investment expenditures as a fraction of GDP
#     - IO
#     - **Structure:** include 60% of spending on:
#         - Administrative and support services”
#         - Miscellaneous professional, scientific, and technical services
#         - Management of companies and enterprises
#     - **Equipment:**
#         - Accounting, consulting, design, and computer services.
#     - **Intellectual property:**
#         - Service output of establishments that manage other units within a company.
#     - **Organizational services:**
#         - Expenditures related to workforce human capital, distribution systems, logistics, product design, and customer and brand capital.
# 2. Labour share by industry
#     -  Integrated Industry-Level Production Account: college, non-college
# 3. Labor income share for consumption and investment sectors
# 4. Something on the labour income share.
