# %% [markdown]
# # `Project overview` for keeping track of progress

# %% [markdown]
# ### `1. To do`
# 1. check model implied values to get empirical $w_I/w_C$.
#
#
# ### `2. Important issues`
# 1. Consumption wage goes down, yet welfare gain is positive, how can this be true?

# %% [markdown]
# git fetch origin
#
# git reset --hard origin/main
