# %% [markdown]
# # `Project overview` for keeping track of progress

# %% [markdown]
# ### `1. To do`
#
# *As per meting with Søren*
# 1. Detaljer begrundelse for $\phi$ i DK: Tjek evt. DREAM (MAKRO), eller andre danske mikroøkonomiske analyser.
#
#     Er det Frisch elasticiteten (mikro kalder den 1/3; makro siger 4)?
#
#     Min figur er ok, men se måske nærmere om de omtale årsager også findes i DK, da må udviklingen også gøre.
#
# 2. Gør tydeligt i formuleringen at "5.2" er nyt og novel $\to$ lav modelbeskriv + 5.2. til Morten Olsen.
# 3. Søren kunne godt lide at have stødprocessen for $(1-\tau_t)$ med i hovedteksten.
# 4. Søren vil have tal på all IRF.
# 5. Chetty (2011), AEJ, redegør for litteraturen på Frisch.s

# %% [markdown]
# git fetch origin
#
# git reset --hard origin/main
